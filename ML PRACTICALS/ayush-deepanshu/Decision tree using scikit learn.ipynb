# %% [markdown]
# # Decision Tree

# %% [markdown]
# A decision tree is a decision support tool that uses a tree-like model of decisions and their possible consequences, including chance event outcomes, resource costs, and utility. It is one way to display an algorithm that only contains conditional control statements.

# %%
from sklearn.datasets import load_iris
from sklearn import tree

# %%
iris = load_iris()
X, y = iris.data, iris.target

# %%
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test = train_test_split(X, y, test_size=0.3)

# %%
clf = tree.DecisionTreeClassifier()
clf = clf.fit(x_train,y_train)

# %%
tree.plot_tree(clf)
# Out:
# [Text(0.5, 0.9166666666666666, 'X[2] <= 4.85\ngini = 0.658\nsamples = 105\nvalue = [27, 40, 38]'),
#  Text(0.16666666666666666, 0.75, 'X[3] <= 0.8\ngini = 0.503\nsamples = 65\nvalue = [27, 37, 1]'),
#  Text(0.08333333333333333, 0.5833333333333334, 'gini = 0.0\nsamples = 27\nvalue = [27, 0, 0]'),
#  Text(0.25, 0.5833333333333334, 'X[3] <= 1.7\ngini = 0.051\nsamples = 38\nvalue = [0, 37, 1]'),
#  Text(0.16666666666666666, 0.4166666666666667, 'gini = 0.0\nsamples = 36\nvalue = [0, 36, 0]'),
#  Text(0.3333333333333333, 0.4166666666666667, 'X[1] <= 3.1\ngini = 0.5\nsamples = 2\nvalue = [0, 1, 1]'),
#  Text(0.25, 0.25, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 1]'),
#  Text(0.4166666666666667, 0.25, 'gini = 0.0\nsamples = 1\nvalue = [0, 1, 0]'),
#  Text(0.8333333333333334, 0.75, 'X[3] <= 1.75\ngini = 0.139\nsamples = 40\nvalue = [0, 3, 37]'),
#  Text(0.75, 0.5833333333333334, 'X[2] <= 5.35\ngini = 0.49\nsamples = 7\nvalue = [0, 3, 4]'),
#  Text(0.6666666666666666, 0.4166666666666667, 'X[0] <= 6.5\ngini = 0.48\nsamples = 5\nvalue = [0, 3, 2]'),
#  Text(0.5833333333333334, 0.25, 'X[3] <= 1.55\ngini = 0.444\nsamples = 3\nvalue = [0, 1, 2]'),
#  Text(0.5, 0.08333333333333333, 'gini = 0.0\nsamples = 2\nvalue = [0, 0, 2]'),
#  Text(0.6666666666666666, 0.08333333333333333, 'gini = 0.0\nsamples = 1\nvalue = [0, 1, 0]'),
#  Text(0.75, 0.25, 'gini = 0.0\nsamples = 2\nvalue = [0, 2, 0]'),
#  Text(0.8333333333333334, 0.4166666666666667, 'gini = 0.0\nsamples = 2\nvalue = [0, 0, 2]'),
#  Text(0.9166666666666666, 0.5833333333333334, 'gini = 0.0\nsamples = 33\nvalue = [0, 0, 33]')]

# %%
predictions = clf.predict(x_test)

# %%
from sklearn.metrics import confusion_matrix, classification_report,accuracy_score
print(confusion_matrix(y_test,predictions))
print(classification_report(y_test,predictions))
print(accuracy_score(y_test,predictions))
# Out:
# [[23  0  0]
#  [ 0  9  1]
#  [ 0  0 12]]
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00        23
#            1       1.00      0.90      0.95        10
#            2       0.92      1.00      0.96        12
#
#     accuracy                           0.98        45
#    macro avg       0.97      0.97      0.97        45
# weighted avg       0.98      0.98      0.98        45
#
# 0.9777777777777777
